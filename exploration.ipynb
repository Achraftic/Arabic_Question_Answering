# %%
import wordcloud
import polars as pl
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pl.read_csv("./dataset/data_preprocessed.csv")

# %%
df
# Out:
# shape: (1_058_708, 2)
# ┌─────────────────────────────────┬─────────────────────────────────┐
# │ question                        ┆ answer                          │
# │ ---                             ┆ ---                             │
# │ str                             ┆ str                             │
# ╞═════════════════════════════════╪═════════════════════════════════╡
# │ هل نسبة المياه ببنين أقل منها … ┆ نعم                             │
# │ هل متوسط العمر بالهند أقل منه … ┆ نعم                             │
# │ هل فرس البحر و النعامة ينتميان… ┆ لا                               │
# │ هل الكثافة السكانية في غانا أع… ┆ لا                               │
# │ هل معدل البطالة بالصين أقل منه… ┆ نعم                             │
# │ …                               ┆ …                               │
# │ التهاب حاد في البنكرياس تم عمل… ┆ يجب أولا تشخيص المشكلة . اذا ا…  │
# │ السلام عليكم انا عايزه اعرف هو…  ┆ لا مؤشر على ذلك نهائيا عليك بع…  │
# ...
